# %% [markdown]
# # DX702 - Week 7 - Reading Quiz

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Question 1
#
#
# Which of the following is **not** a reason that confounders need to be included in a regression?
#
# **Options:**
# - `Otherwise, we could overestimate the true correlation between *X* and *Y*.`
# - Otherwise, we could mistake correlation for causation. ← Incorrect answer
# - Otherwise, we could underestimate the true effect.
# - Otherwise, we could overestimate the true effect.
#
#
# **Feedback:**
# Including a confounder does change the correlation between *X* and *Y* in the data. That’s just a characteristic of the data.
#
# ---
#
# ## Question 2
#
# In the equation:
# **Y = X + 4W + ε**
# Which of the following would **not** happen if we pick a fixed value of *W* and select only the data related to that value?
#
# **Options:**
# - That is a way of controlling for *W*.
# - `*ε* would become correlated with *W*.` ← Correct answer
# - It might allow us to estimate an effect on a small part of the data.
# - We will be throwing out most of the data.
#
# **Feedback:**
# There cannot be a correlation with *W* if our data has only one value of *W* remaining.
#
# ---
#
# ## Question 3
#
# When *X* is correlated with the error term in a nonlinear way:
#
# **Options:**
# - `The correlation will not necessarily be fixed by any of these changes`. ← Correct answer
# - The error term can become uncorrelated with *X* by performing the experiment again enough times.
# - The error term can become uncorrelated with *X* by changing the coefficients.
# - The error term can become uncorrelated with *X* by choosing a different intercept.
#
# **Feedback:**
# A linear regression will not fix a nonlinear correlation unless the appropriate terms are added to the regression (e.g., polynomial terms).
#
# ---
#
# ## Question 4
#
#
# Should we redo an analysis to try to improve the p-values?
#
# **Options:**
# - Yes; it increases the likelihood that we will find a true negative.
# - Yes; it increases the likelihood that we will find a true positive.
# - No; it increases the likelihood that we will find a false negative.
# - `No; it increases the likelihood that we will find a false positive.` ← Correct answer
#
# **Feedback:**
# This is called **p-hacking**, and it’s not allowed. It changes the meaning of the p-value.
#
# ---
#
# ## Question 5
#
# An adjusted *R²* adjusts for:
#
# **Options:**
# - The fact that *R²* is squared instead of cubed.
# - The fact that the total *R²* does not equal the mean *R²*.
# - The fact that *R²* is typically bigger than 1.
# - `The fact that adding more variables will always slightly improve the fit`. ← Correct answer
#
# **Feedback:**
# When more variables are added, the fit improves simply because the variables represent degrees of freedom that can be used to improve the fit.
