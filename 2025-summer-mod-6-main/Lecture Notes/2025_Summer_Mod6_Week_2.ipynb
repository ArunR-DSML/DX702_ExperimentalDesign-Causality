# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import statsmodels.api as sm
import seaborn as sns

from sklearn.neighbors import NearestNeighbors
from statsmodels.stats.outliers_influence import variance_inflation_factor
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Regression

# %% [markdown]
# Z = severity of symptoms
#
# X = dosage of medication given
#
# Y = recovery time

# %% [markdown]
# ### Note: this error term has nonzero mean!  Then it is important to allow for an intercept for Y
# ### Even though no intercept is apparent in the equation for Y

# %%
np.random.seed(0)
numrows     = 1000

Z_severity  = np.minimum(np.maximum(np.random.normal(5, 2, (numrows,)), 0), 10)
X_dosage    = Z_severity + np.random.uniform(0, 10, (numrows,))
Y_recovery  = np.maximum(2 * Z_severity - 0.5 * X_dosage + np.random.uniform(0, 10, (numrows,)), 0)

df          = pd.DataFrame({"X": X_dosage, "Y": Y_recovery, "Z": Z_severity})

# %%
sns.pairplot(df)

# %% [markdown]
# ### Doesn't quite work - confounder (Z) changes X coefficient

# %%
results = sm.OLS(df.Y, sm.add_constant(df[["X"]])).fit()
results.params
# Out:
# const    8.191544
# X        0.163954
# dtype: float64

# %% [markdown]
# ### Works - controlling for the confounder (Z) makes the coefficients correct

# %%
results = sm.OLS(df.Y, sm.add_constant(df[["X", "Z"]])).fit()
results.params
# Out:
# const    4.826447
# X       -0.484418
# Z        2.010365
# dtype: float64

# %% [markdown]
# ### Make X and Z more closely related

# %%
numrows = 10000
np.random.seed(1)

Z_severity  = np.minimum(np.maximum(np.random.normal(5, 2, (numrows,)), 0), 10)
X_dosage    = Z_severity + np.random.uniform(0, 0.5, (numrows,))
Y_recovery  = np.maximum(2 * Z_severity - 0.5 * X_dosage + np.random.uniform(0, 10, (numrows,)), 0)

df2         = pd.DataFrame({"X": X_dosage, "Y": Y_recovery, "Z": Z_severity})

# %%
sns.pairplot(df2)

# %% [markdown]
# ### Doesn't work - confounder changes X coefficient

# %%
results = sm.OLS(df2.Y, sm.add_constant(df2[["X"]])).fit()
results.params
# Out:
# const    4.541978
# X        1.486010
# dtype: float64

# %% [markdown]
# ### Also doesn't work - X and Z are too highly correlated for regression to work.

# %%
results = sm.OLS(df2.Y, sm.add_constant(df2[["X", "Z"]])).fit()
results.params
# Out:
# const    5.028709
# X       -0.679665
# Z        2.177473
# dtype: float64

# %%
np.corrcoef(df2.X, df2.Z)[0,1]
# Out:
# 0.9973382861800946

# %% [markdown]
# ### Again, be sure to include intercept here

# %%
variance_inflation_factor(sm.add_constant(df2[["X", "Z"]]), 1)
# Out:
# 188.09922820443168

# %%
np.random.seed(0)
numrows     = 10000

Z_severity  = np.minimum(np.maximum(np.random.normal(5, 2, (numrows,)), 0), 10)
X_dosage    = np.random.uniform(0, 10, (numrows,))
Y_recovery  = np.maximum(2 * Z_severity - 0.5 * X_dosage + np.random.uniform(0, 10, (numrows,)), 0)

df3         = pd.DataFrame({"X": X_dosage, "Y": Y_recovery, "Z": Z_severity})

# %%
sns.pairplot(df3)

# %% [markdown]
# ### This works!  X coefficient ~-0.5

# %%
results = sm.OLS(df3.Y, sm.add_constant(df3[["X"]])).fit()
results.params
# Out:
# const    14.912259
# X        -0.499406
# dtype: float64

# %%
results.bse
# Out:
# const    0.096022
# X        0.016596
# dtype: float64

# %%
results = sm.OLS(df3.Y, sm.add_constant(df3[["X", "Z"]])).fit()
results.params
# Out:
# const    5.045667
# X       -0.501896
# Z        1.990481
# dtype: float64

# %%
results.bse
# Out:
# const    0.092557
# X        0.009860
# Z        0.014704
# dtype: float64

# %% [markdown]
# # Matching

# %% [markdown]
# ### Goal: want treatment and control items with approximately same Z values
# ### So that differing Z values won't alter calculation of the effect

# %%
numrows     = 10
np.random.seed(2)

Z_severity  = np.minimum(np.maximum(np.random.normal(5, 2, (numrows,)), 0), 10)
X_dosage    = np.random.binomial(1, Z_severity / 10, (numrows,))
Y_recovery  = np.maximum(2 * Z_severity - 2.5 * X_dosage + np.random.uniform(0, 10, (numrows,)), 0)

df_match    = pd.DataFrame({"X": X_dosage, "Y": Y_recovery, "Z": Z_severity})

# %%
treated = df_match[df_match["X"] == 1]
control = df_match[df_match["X"] == 0]

model   = NearestNeighbors(n_neighbors = 1)
result  = model.fit(control[["Z"]])

# %%
prediction = result.kneighbors(treated[["Z"]])

# %%
pd.DataFrame(treated.Z).reset_index()
# Out:
#    index         Z
# 0      0  4.166484
# 1      1  4.887466
# 2      3  8.280542
# 3      5  3.316505
# 4      8  2.884096

# %%
pd.DataFrame(control.Z).reset_index()
# Out:
#    index         Z
# 0      2  0.727608
# 1      4  1.413129
# 2      6  6.005763
# 3      7  2.509424
# 4      9  3.181985

# %%
prediction[1]
# Out:
# array([[4],
#        [2],
#        [2],
#        [4],
#        [4]])

# %%
numrows     = 10000
np.random.seed(0)

Z_severity  = np.minimum(np.maximum(np.random.normal(5, 2, (numrows,)), 0), 10)
X_dosage    = np.random.binomial(1, Z_severity / 10, (numrows,))
Y_recovery  = np.maximum(2 * Z_severity - 2.5 * X_dosage + np.random.uniform(0, 10, (numrows,)), 0)

df_match    = pd.DataFrame({"X": X_dosage, "Y": Y_recovery, "Z": Z_severity})
treated     = df_match[df_match["X"] == 1]
control     = df_match[df_match["X"] == 0]

# %%
treated.Y.mean() - control.Y.mean() # Different values of Z, not just different values of X
# Out:
# 0.4891397480812891

# %%
model   = NearestNeighbors(n_neighbors = 1)
result  = model.fit(control[["Z"]])

# %%
prediction          = result.kneighbors(treated[["Z"]])
matched_controls    = control.iloc[prediction[1].flatten()]

# %% [markdown]
# ## The effect: meant to approximate X = 1 vs X = 0 comparison "as if" Z were held constant

# %%
treated.Y.mean() - matched_controls.Y.mean()
# Out:
# -2.604208745162012

# %%
model           = NearestNeighbors(n_neighbors = 1)
result          = model.fit(treated[["Z"]]) # Memorizing Z values of treated

prediction      = result.kneighbors(control[["Z"]])
matched_treated = treated.iloc[prediction[1].flatten()]

matched_treated.Y.mean() - control.Y.mean()
# Out:
# -2.5326846850959797

# %%
model       = NearestNeighbors(n_neighbors = 1, radius = 0.1)
result      = model.fit(treated[["Z"]]) # Memorizing Z values of treated
prediction  = result.radius_neighbors(control[["Z"]])
prediction[1]
# Out:
# array([array([1234, 2775, 3260, 1342, 1370,  718, 3318, 1078,   97,  497,  772,
#               3496, 3601, 4000, 2824, 3525, 4038, 4807, 3036,  533, 1398,  712,
#               4245,  361, 2746, 3209, 4799, 3405,  232, 2770,  953, 4498, 1781,
#               4756, 1108, 3966, 4782,  778, 3084, 1053, 1533, 4369, 4412,  429,
#               1080, 3110, 4391, 3872, 3542,  894, 4237, 2772,  810,  292, 1355,
#               2019,  329,  691, 2223, 2458, 4908, 4339, 1430, 1193, 2845, 2100,
#               2012, 2712, 1450, 4254, 3450, 1958, 2882, 1505, 3192, 1789, 4131,
#                290, 2034])                                                     ,
#        array([1406, 4633, 3885,  118, 2476, 2602, 4710, 4880, 2656, 2056, 4479,
#               3350, 4327, 3076, 2318,  790, 1562, 4434, 3768, 4225, 3143, 1244,
#                 46, 3332, 3771, 2290, 1190,  923, 2618,  759, 2043,   98, 3265,
#                560, 3754, 3310, 1275, 3792,   71, 2761, 4906, 4094, 2061, 4417,
#               1103,  562, 3699, 3957, 1129,  780, 2360, 4602, 4058,  259,  438,
#               3339, 4333, 4627, 3409,  855,  709, 2140, 1509, 2308,  980,  433,
#               3598, 4061, 3928,  180, 4263,  528, 1744, 1880, 1711, 2869, 3319,
#               3730, 3193,  389, 2402, 3805, 3032,  270,  216,  168, 4650, 2380,
#               2560, 1796, 1594,   68, 1665, 2518, 3434, 2633,  761,  942,  340,
#               3215,   95, 4329, 2867, 4536,  592, 3617, 2509, 3157,  913, 2766,
#               2288, 4421, 2411, 2222,  616, 2756,  679, 1485, 2048,  450, 2587,
#               4540,  884, 4594,  478, 1764,   59, 4282, 3497,    2, 4497, 3658,
#               2139, 2769, 4145, 1851, 2052, 1200, 4361, 1972, 1603,   54,  410,
#               4456, 3010, 2530, 3271, 3296, 4875, 3274, 4353,  826, 1343, 4525,
#               1622, 3618, 3359, 3789, 1214, 2927, 1084, 3932, 1420,  236,  588,
#               3564, 1965, 4618,  403,  770, 4677, 1492, 3956])                 ,
#        array([1427,    5,  452, 3646, 1480, 2036,  788,   75, 1942, 4172, 2780,
#                771, 4562, 4622, 3046, 3881, 4107, 4222, 2990, 3830, 4733, 3804,
#               3382,  363, 3551, 2665, 2201, 3294, 3997,  129, 2386,  297, 4795,
#               3883,  873,  563,  704, 3644, 3024, 3894, 3851, 4406,  568, 2323,
#                925, 1032, 3166, 3605, 1428,  215, 4543, 3911, 2310, 2586, 2604,
#               1298, 3210, 1075, 3499, 4251, 4105, 4635, 4556,  924, 4291, 2714,
#               4648,  154, 4818,  699, 4555, 1818, 4720, 2998,  140, 3105,  226,
#                419, 2653, 4811, 1046, 3330, 3282, 1018,  265, 4059, 3311, 4570,
#               4917, 3685, 4649, 1957, 2947, 2914, 4771, 2213, 2330, 1777, 1625,
#               1854, 2783,  353, 4051, 2434, 3187, 2209, 1995, 2017, 3517, 4161,
#               4911, 1269, 2016,  891, 2521, 3505,   92, 3127, 4048, 3472, 4684,
#               2122, 1871, 2082,  749, 4830, 1671, 3764,  312, 2226, 1101, 1679,
#               1335, 4382, 1434, 1520, 4026, 3631, 1691, 2836,  539, 3592, 2581,
#               2750, 1886, 2677, 2321, 4786, 2757, 4374, 4500, 2242, 3124, 4067,
#               2936, 4449, 4019, 3486,  474, 3495, 4244,  464, 2244, 3889,  246,
#                655, 4519, 2575, 1516, 3378, 1935,  549,  541,   90, 4362, 2408,
#                526, 4638, 2635, 1232, 4165, 1779, 4549, 3906, 4310, 2336,  375,
#               4725, 1824, 2992, 1145,  322, 1970, 3554, 3146, 1030, 4098, 3331,
#                376, 3537, 3403,  760, 3279, 1410, 1349, 2573, 2694, 1008])     ,
#        ...,
#        array([ 259, 4333, 4627, 3409,  855,  709, 2140, 1509,  433, 3598, 4061,
#               3928, 4263,  528, 1744, 1880, 1711, 2869, 3319, 3730, 3193,  389,
#               2402, 3805, 3032,  270,  216,  168, 4650, 2380, 2560, 1796, 1594,
#                 68, 1665, 2518, 3434, 2633,  761,  942,  340, 3215,   95, 4329,
#               2867, 4536,  592, 3617, 2509, 3157,  913, 2766, 2288, 4421, 2411,
#               2222,  616, 2756,  679, 1485, 2048,  450, 2587, 4540,  884, 4594,
#                478, 1764,   59, 4282, 3497,    2, 4497, 3658, 2139, 2769, 4145,
#               1851, 2052, 1200, 4361, 1972, 1603,   54,  410, 4456, 3010, 2530,
#               3271, 3296, 4875, 3274, 4353,  826, 1343, 4525, 1622, 3618, 3359,
#               3789, 1214, 2927, 1084, 3932, 1420,  236,  588, 3564, 1965, 4618,
#                403,  770, 4677, 3822,  863, 3035,  794, 1265, 3850, 2073, 1360,
#               1657, 4565, 2634, 1492, 2004, 3956, 2381, 1985, 3787,  392, 2481,
#               1431, 1365, 2186, 2912, 4303, 2862,  501, 1419, 1096, 2894, 2229,
#               1286, 4727, 3786, 3144,  696,  330, 3933,  354, 2264, 4819, 3068,
#               4093, 1043, 2347, 1787, 3415,  317, 1655, 4318, 1804,  239,  449,
#               4503, 2733, 3664, 1699, 4863, 4241, 2967])                       ,
#        array([2857, 2309, 3540, 2183, 2102, 1730, 1788,  494,  851]),
#        array([1671, 3631, 2750, 1886, 2677, 2321, 4786, 2757, 4374, 4500, 2242,
#               3124, 4067, 2936, 4449, 4019, 3486,  474, 3495, 4244,  464, 2244,
#               3889,  246,  655, 4519, 2575, 1516, 3378, 1935,  549,  541,   90,
#               4362, 2408,  526, 4638, 2635, 1232, 4165, 1779, 4549, 3906, 4310,
#               2336,  375, 4725, 1824, 2992, 1145,  322, 1970, 3554, 3146, 1030,
#               4098, 3331,  376, 3537, 3403,  760, 3279, 1410, 1349, 2909, 1693,
#               3783, 4188, 2906, 2573, 2621, 1532, 4770, 4242, 1841, 2964, 2685,
#               4071, 2182, 1104, 3721, 3041, 4696, 2694, 1008,  134, 3687,  495,
#               3322, 1617, 1266, 2938, 4178, 2415,  122, 4542, 2423,  382, 3357,
#               3003, 1885, 4910,  690,  109, 4200, 2378, 1710, 4532,  337, 1320,
#               3949,  348, 2881, 2739, 4404,  963, 1109, 4269, 2204, 2939, 3848,
#               2101, 1923, 3404, 3835, 2918, 3759, 3718, 3065, 3394,  967, 3639,
#               1952, 1239, 2961, 2085, 2475, 4247,  182, 3884, 3232, 1017, 2208,
#               2849, 3149, 3742, 1478, 4064, 3785,  590, 1272, 2698,  398, 3526,
#               4620, 3197,  991, 2584, 3812, 4898, 3838, 1902, 1292, 2047, 3042,
#               1632, 2015, 1599, 3006, 2344, 4664, 3948, 4575, 3358, 3887, 4713,
#               1141, 1383, 2107, 4168, 1257, 4104, 4897, 1123, 2567,  222, 2600,
#               3626, 2723, 4230, 2847, 2817,  740,  868,  951, 1695, 4564, 1613,
#               3555, 1662, 3277, 1549, 3030, 1148])                             ],
#       dtype=object)

# %%
control.iloc[0]
# Out:
# X    0.000000
# Y    8.482639
# Z    3.045444
# Name: 5, dtype: float64

# %%
treated.iloc[[1234, 2775, 3260, 1342, 1370,  718, 3318, 1078,   97,  497,  772,
              3496, 3601, 4000, 2824, 3525, 4038, 4807, 3036,  533, 1398,  712,
              4245,  361, 2746, 3209, 4799, 3405,  232, 2770,  953, 4498, 1781,
              4756, 1108, 3966, 4782,  778, 3084, 1053, 1533, 4369, 4412,  429,
              1080, 3110, 4391, 3872, 3542,  894, 4237, 2772,  810,  292, 1355,
              2019,  329,  691, 2223, 2458, 4908, 4339, 1430, 1193, 2845, 2100,
              2012, 2712, 1450, 4254, 3450, 1958, 2882, 1505, 3192, 1789, 4131,
               290, 2034]]
# Out:
#       X          Y         Z
# 2532  1  12.009601  2.956173
# 5570  1   5.622265  2.957148
# 6572  1  13.062126  2.962468
# 2742  1  10.799338  2.993468
# 2791  1   4.602351  3.001140
# ...  ..        ...       ...
# 6409  1   5.492634  3.119390
# 3631  1   9.144218  3.107559
# 8353  1  13.211199  3.134792
# 598   1   6.689086  3.139687
# 4112  1   9.624424  3.144350
#
# [79 rows x 3 columns]
